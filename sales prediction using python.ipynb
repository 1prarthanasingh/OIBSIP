# %% [markdown]
#
#      ##Oasis Infobyte
# ### Name:Prarthana Singh
# ## Task 3- Sales prediction using python

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
ad = pd.read_csv("Advertising.csv")
ad.shape
# Out:
# (200, 5)

# %%
ad.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
#Checking for missing values
ad.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
ad.drop(['Unnamed: 0'],axis=1,inplace=True)
ad.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
ad.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('TV Distribution Plot')
sns.distplot(ad.TV)
# Out:
# <AxesSubplot:title={'center':'TV Distribution Plot'}, xlabel='TV', ylabel='Density'>

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Radio Distribution Plot')
sns.distplot(ad.Radio)
# Out:
# <AxesSubplot:title={'center':'Radio Distribution Plot'}, xlabel='Radio', ylabel='Density'>

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Newspaper Distribution Plot')
sns.distplot(ad.Newspaper)
# Out:
# <AxesSubplot:title={'center':'Newspaper Distribution Plot'}, xlabel='Newspaper', ylabel='Density'>

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
plt.title('Sales Distribution Plot')
sns.distplot(ad.Sales)
# Out:
# <AxesSubplot:title={'center':'Sales Distribution Plot'}, xlabel='Sales', ylabel='Density'>

# %%
ad.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
col = ['TV', 'Radio', 'Newspaper']

# %%
for i in col:
    sns.jointplot(i,"Sales", data=ad,kind="reg")
    plt.show()
    print("="*70)
# Out:
# ======================================================================
# ======================================================================
# ======================================================================

# %%
sns.pairplot(ad)
plt.show()

# %%
ad.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(ad.corr(),annot=True)
plt.show()

# %%
X=ad[col]
X.head()
# Out:
#       TV  Radio  Newspaper
# 0  230.1   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3
# 3  151.5   41.3       58.5
# 4  180.8   10.8       58.4

# %%
y=ad.Sales
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
print("Traing Data Shape of x and y respectively:  ", X_train.shape, y_train.shape)
print("Testing Data Shape of x and y respectively:  ", X_test.shape, y_test.shape)
# Out:
# Traing Data Shape of x and y respectively:   (160, 3) (160,)
# Testing Data Shape of x and y respectively:   (40, 3) (40,)

# %%
X_train
# Out:
#         TV  Radio  Newspaper
# 134   36.9   38.6       65.6
# 66    31.5   24.6        2.2
# 26   142.9   29.3       12.6
# 113  209.6   20.6       10.7
# 168  215.4   23.6       57.6
# ..     ...    ...        ...
# 67   139.3   14.5       10.2
# 192   17.2    4.1       31.6
# 117   76.4    0.8       14.8
# 47   239.9   41.5       18.5
# 172   19.6   20.1       17.0
#
# [160 rows x 3 columns]

# %%
X_test
# Out:
#         TV  Radio  Newspaper
# 18    69.2   20.5       18.3
# 170   50.0   11.6       18.4
# 107   90.4    0.3       23.2
# 98   289.7   42.3       51.2
# 177  170.2    7.8       35.2
# 182   56.2    5.7       29.7
# 5      8.7   48.9       75.0
# 146  240.1    7.3        8.7
# 12    23.8   35.1       65.9
# 152  197.6   23.3       14.2
# 61   261.3   42.7       54.7
# 125   87.2   11.8       25.9
# 180  156.6    2.6        8.3
# 154  187.8   21.1        9.5
# 80    76.4   26.7       22.3
# 7    120.2   19.6       11.6
# 33   265.6   20.0        0.3
# 130    0.7   39.6        8.7
# 37    74.7   49.4       45.7
# 74   213.4   24.6       13.1
# 183  287.6   43.0       71.8
# 145  140.3    1.9        9.0
# 45   175.1   22.5       31.5
# 159  131.7   18.4       34.6
# 60    53.5    2.0       21.4
# 123  123.1   34.6       12.4
# 179  165.6   10.0       17.6
# 185  205.0   45.1       19.6
# 122  224.0    2.4       15.6
# 44    25.1   25.7       43.3
# 16    67.8   36.6      114.0
# 55   198.9   49.4       60.0
# 150  280.7   13.9       37.0
# 111  241.7   38.0       23.2
# 22    13.2   15.9       49.6
# 189   18.7   12.1       23.4
# 129   59.6   12.0       43.1
# 4    180.8   10.8       58.4
# 83    68.4   44.5       35.6
# 106   25.0   11.0       29.7

# %%
y_train
# Out:
# 134    10.8
# 66      9.5
# 26     15.0
# 113    15.9
# 168    17.1
#        ...
# 67     13.4
# 192     5.9
# 117     9.4
# 47     23.2
# 172     7.6
# Name: Sales, Length: 160, dtype: float64

# %%
y_test
# Out:
# 18     11.3
# 170     8.4
# 107     8.7
# 98     25.4
# 177    11.7
# 182     8.7
# 5       7.2
# 146    13.2
# 12      9.2
# 152    16.6
# 61     24.2
# 125    10.6
# 180    10.5
# 154    15.6
# 80     11.8
# 7      13.2
# 33     17.4
# 130     1.6
# 37     14.7
# 74     17.0
# 183    26.2
# 145    10.3
# 45     14.9
# 159    12.9
# 60      8.1
# 123    15.2
# 179    12.6
# 185    22.6
# 122    11.6
# 44      8.5
# 16     12.5
# 55     23.7
# 150    16.1
# 111    21.8
# 22      5.6
# 189     6.7
# 129     9.7
# 4      12.9
# 83     13.6
# 106     7.2
# Name: Sales, dtype: float64

# %%
X_train=X_train.astype(int)
y_train=y_train.astype(int)
X_test=X_test.astype(int)
y_test=y_test.astype(int)

# %%
from sklearn.preprocessing import StandardScaler
Sc=StandardScaler()
X_train_scaled=Sc.fit_transform(X_train)

# %%
X_test_scaled=Sc.fit_transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(X_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test_scaled)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.8303910270450665

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test,y_pred,c='g')
